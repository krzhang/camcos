# %%
df = read.csv("KmeanClusters.csv")

# %%
head(df)
# Out:
#   X executionGas callDataUsage label label6
# 1 0 515877        1812         0     0
# 2 1 515865        1824         0     0
# 3 2 149356         644         0     0
# 4 3  71000           0         0     0
# 5 4 498176        1824         0     0
# 6 5 458886       10916         0     0

# %%
df = df[,-1]

# %%
head(df)
# Out:
#   executionGas callDataUsage label label6
# 1 515877        1812         0     0
# 2 515865        1824         0     0
# 3 149356         644         0     0
# 4  71000           0         0     0
# 5 498176        1824         0     0
# 6 458886       10916         0     0

# %%
library(ggplot2)

# %%
ggplot(df)  + 
  geom_point(aes(x = log(executionGas), y = log(callDataUsage),color=factor(label))) +theme_bw()
# Out:
# plot without title

# %%
ggplot(df)  + 
  geom_point(aes(x = log(executionGas), y = log(callDataUsage),color=factor(label6))) +theme_bw()+ggtitle("KMean Clusters")
ggsave("plotKMeansclusters.png")
# Out:
# Saving 6.67 x 6.67 in image
# plot without title
